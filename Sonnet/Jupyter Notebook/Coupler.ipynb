# %% [markdown]
# # Coupleur micro-onde

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np
import skrf as rf
from IPython.display import Image, display
from scipy.optimize import curve_fit
prop_cycle = rcParams['axes.prop_cycle']   
colors = prop_cycle.by_key()['color']

# %% [markdown]
# ## Coupleur directionnel

# %%
path_fig="..//Figures/" 
Image(filename=path_fig+"Coupleur.png")

# %% [markdown]
# Reproduire le coupleur hybride représenté ci-dessus en utilisant la microstrip étudiée précédemment.
#
# - Simuler cet élément à 4 ports entre $8\,\mathrm{GHz}$ et $16\,\mathrm{GHz}$.
# - Vérifier que les différents ports de ce coupleur sont bien adaptés.
# - Calculer la valeur de $|\det S|$ à toutes les fréquences, commenter, et supprimer la dissipation du substrat si besoin.
# - Mesurer le couplage moyen entre les ports 1 et 2, puis entre les ports 1 et 4.

# %% [markdown]
# ## Diviseur de d'amplitude

# %% [markdown]
# Simuler le coupleur à 3 ports ci-dessous en choisissant la valeur des trois résistances afin de réaliser un diviseur d’amplitude.

# %%
path="..//Figures/" 
Image(filename=path_fig+"Amplitude_divider.png")

# %% [markdown]
# ## Diviseur de puissance

# %% [markdown]
# Le diviseur de puissance est nécessairement un coupleur à 4 ports non dissipatif. Reproduire le coupleur *branch-line coupler* ci-dessous pour qu'il fonctionne à $5\,\mathrm{GHz}$.
# - Vérifier que la puissance est bien divisée entre les sorties \#2 et \#3.
# - Vérifier que ce coupleur réalise un hybride à $90^\circ$.

# %%
Image(filename=path_fig+"Power_divider.png")
