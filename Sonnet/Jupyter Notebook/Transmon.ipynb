# %% [markdown]
# # LC resonator in Hanger configuration

# %%
import matplotlib.pyplot as plt
from IPython.display import Image, display
from matplotlib import rcParams
import numpy as np
import skrf as rf
from scipy.optimize import curve_fit
prop_cycle = rcParams['axes.prop_cycle']   
colors = prop_cycle.by_key()['color']

# %% [markdown]
# ### Capacité interdifitée

# %%
path="..//Figures/" 
Image(filename=path+"Qubit_Hanger.png")

# %% [markdown]
# - Reproduire la capacité interdigitée utilisée pour réaliser le transmon de l'échantillon ci-dessus (Nature 454, 315–318 (2008)). On respectera grossièrement les dimenssions et on simulera la capacité en l'excitant avec des [ports internes balancés](https://www.sonnetsoftware.com/support/doc_19.52/Topics/Ports/Co-calibrated_Internal_Ports.htm?agt=index).
# - Déduire la capcité du transmon en simulant la matrice des admittances $Y_{ij}=\left. \frac{I_{i}^{(-)}}{V_j^{(+)}} \right|_{V_{k\neq 0}^{(+)}=0}$
# - Déduire l'inductance qu'il faut utiliser pour simuler une jonction Josephson réalisant un qubit de fréquence plasma $f_q=5 \, \mathrm{GHz}$. Vérifier que le zéro de l'admittance du résonateur est bien égal à $f_q$: $Im(Y_{ij}(f_q))=0$

# %% [markdown]
# ### Couplage du résonanteur à une microstrip

# %% [markdown]
# Coupler capacitivement le résonteur à la microstrip étudiée précédemment
# - paramétrer la force du couplage en contrôlant la distance $g$ entre la microstrip et la capacité.
# - étudier la résonance pour différentes valeurs de $g$ (Anchored dimension parameter).
# - déduire de la mesure de $S_{21}$ le facteur de qualité de couplge $Q_c(g)$ ainsi que la fréquence de résonance $f_0(g)$

# %% [markdown]
# ## Dissipation interne

# %% [markdown]
# Coupler capacitivement le résonteur à la microstrip étudiée précédemment de telle sorte que $Qc\simeq 10^6$
# - introduire une dissipasion interne en ajoutant un résistance $R$ en parallèle. $R$ doit être comparée à $Z_c=\sqrt{\frac{L}{C}}$,
# - étudier la résonance pour différentes valeurs de $R$,
# - déduire de la mesure de $S_{21}$ le facteur de qualité intrinsèque $Q_i(R)$ ainsi que la fréquence de résonance $f_0(g)$.
