# %% [markdown]
# # Jupyter Notebook Server
#
# Chaque groupe possède son propre espace de stockage et de travail. Des notebooks d'exemples et de travail sont préchargés dans les répertoires:
# - Sonnet, jour 1&2
# - Quantum Machine, jour 3
# - Transmon, jour 3&4
#
# Si vous effacez par erreur des fichiers, ou si l'enseignant vous demande de charger la nouvelle version des fichiers, vous pouvez le faire en cliquant sur le lien ci-dessous:
#
# [https://jupyter.lps.u-psud.fr/hub/user-redirect/git-pull?repo=https://github.com/NS2LPS/Arteq](https://jupyter.lps.u-psud.fr/hub/user-redirect/git-pull?repo=https://github.com/NS2LPS/Arteq)
